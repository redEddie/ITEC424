# %% [markdown]
# Brute-Force Matching with ORB Descriptors
#
# to match features between two images
#
# find the queryImage in trainImage using feature matching.

# %%
# loading images, finding descriptors

import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (18).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate ORB detector
orb = cv.ORB_create()
 
# find the keypoints and descriptors with ORB
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv.BFMatcher(cv.NORM_HAMMING, crossCheck=True)
 
# Match descriptors.
matches = bf.match(des1,des2)
 
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)
 
# Draw first 10 matches.
img3 = cv.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x12ca4a69c50>, None)

# %% [markdown]
# Brute-Force Matching with SIFT Descriptors and Ratio Test

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (19).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x12ca4ab6550>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (2).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x12ca4cd9c50>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (17).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 28
#      25 # cv.drawMatchesKnn expects list of lists as matches.
#      26 img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
# ---> 28 plt.imshow(img3),plt.show()
#
# File c:\Users\cpscc\miniconda3\envs\cv\Lib\site-packages\matplotlib\pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\cpscc\miniconda3\envs\cv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (18).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x20988fb0cd0>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (20).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x209880f9c50>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./crossing.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (21).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2098901f750>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./slow3.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (25).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x224e3dcdd50>, None)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
 
img1 = cv.imread('./hobanwu2.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (14).jpg',cv.IMREAD_GRAYSCALE) # trainImage
 
# Initiate SIFT detector
sift = cv.SIFT_create()
 
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
 
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
 
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
 
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
 
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x12cc6156550>, None)

# %%
import numpy as np

# Assuming kp2 is a tuple containing cv2.KeyPoint objects
decimal_points = []

for kp in kp1:
    x = kp.pt[0]  # Extract x-coordinate
    y = kp.pt[1]  # Extract y-coordinate
    decimal_points.append((x, y))  # Append (x, y) tuple to the list

# Print the list of decimal points
np.array(decimal_points).shape

import sys
with open('kp1.txt', 'w') as f:
    sys.stdout = f
    print(decimal_points)
    sys.stdout = sys.__stdout__

# %%
good_kp = np.zeros((len(good), 2))
for idx in range(len(good)):
    # print(good[idx][0].queryIdx)
    good_kp[idx] = kp2[good[idx][0].trainIdx].pt
    # print(kp2[good[idx][0].trainIdx].pt)

rgb_image = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
plt.imshow(rgb_image, interpolation='bicubic')
plt.plot(good_kp[:, 0], good_kp[:, 1], 'ro', markersize=1)
# plt.show()
print(good_kp)
# Out:
# [[1145.56225586 1123.59802246]
#  [1145.56225586 1123.59802246]
#  [1168.46630859 1100.81970215]
#  [1200.50170898 1086.39404297]
#  [1286.45800781 1278.81213379]
#  [1371.52087402 1661.05529785]
#  [1371.52087402 1661.05529785]
#  [1599.14489746 2436.08984375]
#  [1472.3614502  2028.94543457]
#  [1495.95556641 2158.82836914]
#  [1496.49206543 2077.27539062]
#  [1496.49206543 2077.27539062]
#  [1496.49206543 2077.27539062]
#  [1582.31115723 1616.10180664]
#  [1604.46386719 1955.47229004]
#  [1615.38256836 1947.25817871]
#  [1618.03259277 1869.82421875]
#  [1618.03259277 1869.82421875]
#  [1643.39904785 1939.41455078]
#  [1643.39904785 1939.41455078]
#  [1681.5402832  1951.20739746]
#  [1699.24121094 1961.15820312]
#  [1705.18859863 1865.27392578]
#  [1734.25219727 1224.68469238]
#  [1761.96191406 1255.09509277]
#  [ 992.21697998 2072.00732422]]

# %%
kp2[idx].pt
# Out:
# (3.0321640968322754, 2831.176513671875)

# %%
kp = np.zeros((len(kp2), 2))
for idx in range(len(kp2)):
    # print(good[idx][0].queryIdx)
    kp[idx] = kp2[idx].pt
    # print(kp2[good[idx][0].trainIdx].pt)

rgb_image = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
plt.imshow(rgb_image, interpolation='bicubic')
plt.plot(kp[:, 0], kp[:, 1], 'ro', markersize=1)

# %% [markdown]
# FLANN based Matcher

# %%
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)

# %%
FLANN_INDEX_LSH = 6
index_params= dict(algorithm = FLANN_INDEX_LSH,
table_number = 6, # 12
key_size = 12, # 20
multi_probe_level = 1) #2

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img1 = cv.imread('./slow3.jpg',cv.IMREAD_GRAYSCALE) # queryImage
img2 = cv.imread('./image/img (9).jpg',cv.IMREAD_GRAYSCALE) # trainImage

# Initiate SIFT detector
sift = cv.SIFT_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50) # or pass empty dictionary

flann = cv.FlannBasedMatcher(index_params,search_params)

matches = flann.knnMatch(des1,des2,k=2)

# Need to draw only good matches, so create a mask
matchesMask = [[0,0] for i in range(len(matches))]

# ratio test as per Lowe's paper
for i,(m,n) in enumerate(matches):
    if m.distance < 0.7*n.distance:
        matchesMask[i]=[1,0]

draw_params = dict(matchColor = (0,255,0),
singlePointColor = (255,0,0),
matchesMask = matchesMask,
flags = cv.DrawMatchesFlags_DEFAULT)

img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,matches,None,**draw_params)

plt.imshow(img3,),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x22484da88d0>, None)
